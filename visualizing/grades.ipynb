# %%
import pandas as pd
# %matplotlib inline
import matplotlib
matplotlib.style.use('ggplot')

# %%
student_dataset = pd.read_csv('./students.data', index_col=0)
student_dataset.head(5)
# Out:
#     sex  age  address  famsize  Pstatus  Medu  Fedu  traveltime  studytime  \
# id
# 0     1   18        0        1        0     4     4           2          2
# 1     1   17        0        1        1     1     1           1          2
# 2     1   15        0        0        1     1     1           1          2
# 3     1   15        0        1        1     4     2           1          3
# 4     1   16        0        1        1     3     3           1          2
#
#     failures ...  famrel  freetime  goout  Dalc  Walc  health  absences  G1  \
# id           ...
# 0          0 ...       4         3      4     1     1       3         4   0
# 1          0 ...       5         3      3     1     1       3         2   9
# 2          0 ...       4         3      2     2     3       3         6  12
# 3          0 ...       3         2      2     1     1       5         0  14
# 4          0 ...       4         3      2     1     2       5         0  11
#
#     G2  G3
# id
# 0   11  11
# ...

# %%
my_series = student_dataset.G3
my_dataframe = student_dataset[['G3', 'G2', 'G1']]

# %%
my_series.plot.hist(alpha=0.5)
my_dataframe.plot.hist(alpha=0.5)

# %%
my_series.plot.hist(alpha=0.5, normed=True)
my_dataframe.plot.hist(alpha=0.5, normed=True)

# %%
student_dataset.plot.scatter(x='G1', y='G3')

# %%
student_dataset.plot.scatter(x='absences', y='failures')

# %%
student_dataset.columns
# Out:
# Index([u'sex', u'age', u'address', u'famsize', u'Pstatus', u'Medu', u'Fedu',
#        u'traveltime', u'studytime', u'failures', u'schoolsup', u'famsup',
#        u'paid', u'activities', u'nursery', u'higher', u'internet', u'romantic',
#        u'famrel', u'freetime', u'goout', u'Dalc', u'Walc', u'health',
#        u'absences', u'G1', u'G2', u'G3'],
#       dtype='object')

# %%
student_dataset.plot.scatter(x='studytime', y='failures')

# %%
# student_dataset.plot.scatter(x='studytime', z='absences', y='failures') have to use matplotlib directly
import matplotlib
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
plt.suptitle("Failures related to studytime and absences")

# %%
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Study Time')
ax.set_ylabel('Failures')
ax.set_zlabel('Absences')
ax.scatter(student_dataset.studytime, student_dataset.failures, student_dataset.absences, c='r', marker='.')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Final Grade')
ax.set_ylabel('First Grade')
ax.set_zlabel('Daily Alcohol')
ax.scatter(student_dataset.G1, student_dataset.G3, student_dataset['Dalc'], c='r', marker='.')
plt.show()

# %%
# %matplotlib qt5

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Final Grade')
ax.set_ylabel('First Grade')
ax.set_zlabel('Daily Alcohol')
ax.scatter(student_dataset.G1, student_dataset.G3, student_dataset['Dalc'], c='r', marker='.')
plt.show()

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('Study Time')
ax.set_ylabel('Failures')
ax.set_zlabel('Absences')
ax.scatter(student_dataset.studytime, student_dataset.failures, student_dataset.absences, c='r', marker='.')
plt.show()
